# %% [markdown]
# # Setting

# %% [markdown]
# ## A. Install `Kaggle API`

# %%
lst = [1,2,3]

# %% [markdown]
# ### 1. Install `Kaggle CLI`

# %%
# Install Kaggle CLI(Command Line Interface)
# !pip3 install kaggle --user

# %%
# Check that Kaggle CLI is properly installed
# !kaggle
# Out:
# usage: kaggle [-h] [-v] {competitions,c,datasets,d,kernels,k,config} ...
# kaggle: error: the following arguments are required: command

# %% [markdown]
# ### 2. `API` credentials
# * Download `API` from Kaggle website ('Account' tab)

# %% [markdown]
# ![kaggle-api.png](attachment:kaggle-api.png)

# %%
# !mkdir /root/.kaggle

# %%
# locate kaggle.json in /root/.kaggle
# !mv /home/jupyter/root/kaggle.json /root/.kaggle/kaggle.json

# %%
# For security, ensure that other users of my computer do not have read access to my credentials
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# Check Kaggle API is properly working
# !kaggle competitions list
# Out:
# ref                                            deadline             category            reward  teamCount  userHasEntered
# ---------------------------------------------  -------------------  ---------------  ---------  ---------  --------------
# contradictory-my-dear-watson                   2030-07-01 23:59:00  Getting Started     Prizes        197           False
# gan-getting-started                            2030-07-01 23:59:00  Getting Started     Prizes        325           False
# tpu-getting-started                            2030-06-03 23:59:00  Getting Started  Knowledge        959           False
# digit-recognizer                               2030-01-01 00:00:00  Getting Started  Knowledge       5984           False
# titanic                                        2030-01-01 00:00:00  Getting Started  Knowledge      49676           False
# house-prices-advanced-regression-techniques    2030-01-01 00:00:00  Getting Started  Knowledge      12969           False
# ...

# %% [markdown]
# ## B. Kaggle Competition: RSNA Pneumonia Detection Challenge

# %% [markdown]
# ![rsna-pneumonia-detection-challenge.png](attachment:rsna-pneumonia-detection-challenge.png)

# %% [markdown]
# ### 1. Data download
# * 'Rules' tab : "I understand and accept the rules for this competition."

# %% [markdown]
# ![kaggle-rules.png](attachment:kaggle-rules.png)

# %% [markdown]
# * 'Data' tab : download dataset
#
# ![kaggle-data-download.png](attachment:kaggle-data-download.png)

# %%
# !kaggle competitions download -c rsna-pneumonia-detection-challenge
# Out:
# ...
# 100%|█████████████████████████████████████▉| 3.66G/3.66G [06:34<00:00, 10.9MB/s]
# 100%|██████████████████████████████████████| 3.66G/3.66G [06:34<00:00, 9.97MB/s]

# %%
#Code by Rahul: https://stackoverflow.com/a/3451150

import zipfile

PATH_TO_ZIP_FILE = '/home/jupyter/home/task1_rsna_pneumonia/rsna-pneumonia-detection-challenge.zip'
DIRECTORY_TO_EXTRACT_TO = '/home/jupyter/home/task1_rsna_pneumonia/data/'

with zipfile.ZipFile(PATH_TO_ZIP_FILE, 'r') as zip_ref:
    zip_ref.extractall(DIRECTORY_TO_EXTRACT_TO)
